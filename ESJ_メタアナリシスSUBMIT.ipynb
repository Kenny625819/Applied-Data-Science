# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenny625819/Applied-Data-Science/blob/main/ESJ_%E3%83%A1%E3%82%BF%E3%82%A2%E3%83%8A%E3%83%AA%E3%82%B7%E3%82%B9SUBMIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# MESCC Meta-analysis
# Clean vs expanded vs complete paralysis
# Google Colab full submission code
# Figure size unchanged: FIGSIZE = (8, 8)
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# ============================================================
# Global style
# ============================================================

BASE_FONT = 14
TITLE_FONT = 16
FIGSIZE = (8, 8)

plt.rcParams.update({
    "font.size": BASE_FONT,
    "axes.titlesize": TITLE_FONT,
    "axes.labelsize": BASE_FONT,
    "xtick.labelsize": BASE_FONT,
    "ytick.labelsize": BASE_FONT,
    "legend.fontsize": BASE_FONT,
    "font.family": "DejaVu Sans",
    "axes.edgecolor": "black",
    "axes.linewidth": 1.2,
    "xtick.color": "black",
    "ytick.color": "black",
    "text.color": "black",
    "axes.labelcolor": "black",
})

# ============================================================
# Dataset
# event = postoperative ambulatory recovery
# Chen 2007 excluded: no clear ambulatory recovery / heterogeneous definitions
# ============================================================

data = pd.DataFrame({
    "Study": [
        "Kim 2011",
        "Tateiwa 2018",
        "Ohashi 2017",
        "Kinoshita 2023",
        "Li 2024",
        "Wanman 2025",
        "Kim HCC 2011",
        "Gokaslan 1998",
        "Park NSCLC 2016",
        "Younsi 2021"
    ],
    "n": [57, 31, 82, 113, 37, 111, 14, 13, 39, 28],
    "event": [39, 17, 50, 70, 22, 61, 4, 10, 23, 7],
    "analysis_group": [
        "Clean cohort",
        "Clean cohort",
        "Clean cohort",
        "Clean cohort",
        "Clean cohort",
        "Clean cohort",
        "Expanded cohort",
        "Expanded cohort",
        "Expanded cohort",
        "Complete paralysis"
    ],
    "notes": [
        "Non-ambulatory cohort",
        "Non-ambulatory cohort",
        "Non-ambulatory cohort",
        "Non-ambulatory cohort",
        "Non-ambulatory cohort",
        "Non-ambulatory >48 h cohort",
        "Tumor-specific HCC cohort",
        "Anterior vertebrectomy; selected thoracic metastases",
        "Tumor-specific NSCLC cohort",
        "Complete motor paralysis cohort"
    ]
})

data["p"] = data["event"] / data["n"]

clean6 = data[data["analysis_group"] == "Clean cohort"].copy()
expanded10 = data.copy()
paralysis = data[data["analysis_group"] == "Complete paralysis"].copy()

# ============================================================
# Meta-analysis function
# Random-effects model using logit transformation
# ============================================================

def run_meta(df, title, filename_prefix, x_label="Postoperative ambulatory recovery rate"):
    df = df.copy()
    df["p"] = df["event"] / df["n"]

    # Continuity correction
    df["event_cc"] = df["event"] + 0.5
    df["n_cc"] = df["n"] + 1
    df["nonevent_cc"] = df["n_cc"] - df["event_cc"]

    # Logit transformation
    df["p_cc"] = df["event_cc"] / df["n_cc"]
    df["logit"] = np.log(df["p_cc"] / (1 - df["p_cc"]))
    df["var"] = 1 / df["event_cc"] + 1 / df["nonevent_cc"]

    # Fixed-effect estimate
    w_fixed = 1 / df["var"]
    mean_fixed = np.sum(w_fixed * df["logit"]) / np.sum(w_fixed)

    # Heterogeneity
    Q = np.sum(w_fixed * (df["logit"] - mean_fixed) ** 2)
    dof = len(df) - 1

    tau2 = 0 if len(df) == 1 else max(
        0,
        (Q - dof) / (np.sum(w_fixed) - np.sum(w_fixed ** 2) / np.sum(w_fixed))
    )

    # Random-effects estimate
    w_random = 1 / (df["var"] + tau2)
    mean_random = np.sum(w_random * df["logit"]) / np.sum(w_random)
    se_random = np.sqrt(1 / np.sum(w_random))

    def inv_logit(x):
        return np.exp(x) / (1 + np.exp(x))

    pooled = inv_logit(mean_random)
    ci_low = inv_logit(mean_random - 1.96 * se_random)
    ci_high = inv_logit(mean_random + 1.96 * se_random)

    I2 = 0 if len(df) == 1 else max(0, (Q - dof) / Q) * 100 if Q > 0 else 0

    # Study-level CI for plotting
    df["se_p"] = np.sqrt((df["p"] * (1 - df["p"])) / df["n"])
    df["ci_low"] = np.maximum(0, df["p"] - 1.96 * df["se_p"])
    df["ci_high"] = np.minimum(1, df["p"] + 1.96 * df["se_p"])

    print("\n================================================")
    print(title)
    print("================================================")
    display(df[["Study", "n", "event", "p", "ci_low", "ci_high", "analysis_group", "notes"]])
    print(f"Pooled ambulatory recovery rate = {pooled:.3f}")
    print(f"95% CI = {ci_low:.3f}–{ci_high:.3f}")
    print(f"I² = {I2:.1f}%")
    print(f"Tau² = {tau2:.4f}")

    df[["Study", "n", "event", "p", "ci_low", "ci_high", "analysis_group", "notes"]].to_csv(
        f"{filename_prefix}_data.csv", index=False
    )

    # Forest plot
    plot_df = df.iloc[::-1].reset_index(drop=True)
    y = np.arange(len(plot_df))

    xerr_lower = plot_df["p"] - plot_df["ci_low"]
    xerr_upper = plot_df["ci_high"] - plot_df["p"]

    fig, ax = plt.subplots(figsize=FIGSIZE)

    ax.errorbar(
        plot_df["p"],
        y,
        xerr=[xerr_lower, xerr_upper],
        fmt="o",
        color="black",
        ecolor="black",
        elinewidth=1.5,
        capsize=5,
        markersize=6
    )

    ax.axvline(
        pooled,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label=f"Pooled = {pooled:.2f}"
    )

    ax.set_yticks(y)
    ax.set_yticklabels(plot_df["Study"])
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.set_xlim(0, 1.0)
    ax.legend(frameon=False)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    plt.tight_layout()

    fig.savefig(f"{filename_prefix}.png", dpi=600, bbox_inches="tight")
    fig.savefig(f"{filename_prefix}.pdf", bbox_inches="tight")

    plt.show()

    return {
        "analysis": title,
        "number_of_studies": len(df),
        "total_patients": int(df["n"].sum()),
        "total_events": int(df["event"].sum()),
        "crude_recovery_rate": df["event"].sum() / df["n"].sum(),
        "pooled_ambulatory_recovery_rate": pooled,
        "ci_low": ci_low,
        "ci_high": ci_high,
        "I2": I2,
        "tau2": tau2,
        "Q": Q,
        "dof": dof
    }

# ============================================================
# 1. Main analysis: clean 6 studies
# ============================================================

clean_result = run_meta(
    clean6,
    "Clean cohort analysis",
    "Figure1_clean6_forest_plot"
)

# ============================================================
# 2. Expanded analysis: 10 studies
# ============================================================

expanded_result = run_meta(
    expanded10,
    "Expanded analysis including additional abstract-based studies",
    "Figure2_expanded10_forest_plot"
)

# ============================================================
# 3. Complete paralysis subgroup
#    Only one study currently available, so this is descriptive
# ============================================================

paralysis_result = run_meta(
    paralysis,
    "Complete paralysis subgroup",
    "Figure3_complete_paralysis_forest_plot"
)

# ============================================================
# 4. Optional: Expanded analysis excluding Gokaslan
#    Gokaslan is surgically and anatomically selected, so this is useful
# ============================================================

expanded_no_gokaslan = expanded10[expanded10["Study"] != "Gokaslan 1998"].copy()

expanded_no_gokaslan_result = run_meta(
    expanded_no_gokaslan,
    "Sensitivity analysis: expanded cohort excluding Gokaslan",
    "Figure4_expanded_excluding_Gokaslan"
)

# ============================================================
# 5. Summary figure: clean vs expanded vs complete paralysis
# ============================================================

summary_results = pd.DataFrame([
clean_result,
expanded_result,
paralysis_result,
expanded_no_gokaslan_result
])

summary_results["rate_percent"] = summary_results["pooled_ambulatory_recovery_rate"] * 100
summary_results["ci_low_percent"] = summary_results["ci_low"] * 100
summary_results["ci_high_percent"] = summary_results["ci_high"] * 100

# Short display labels for figure
label_map = {
"Clean cohort analysis": "Clean cohort\nanalysis",
"Expanded analysis including additional abstract-based studies": "Expanded analysis\n(including abstract-based studies)",
"Complete paralysis subgroup": "Complete paralysis\nsubgroup",
"Sensitivity analysis: expanded cohort excluding Gokaslan": "Sensitivity analysis\n(excluding Gokaslan)"
}

summary_results["display_label"] = summary_results["analysis"].map(label_map)

# Desired order from top to bottom
order = [
"Clean cohort analysis",
"Expanded analysis including additional abstract-based studies",
"Complete paralysis subgroup",
"Sensitivity analysis: expanded cohort excluding Gokaslan"
]

plot_summary = summary_results.set_index("analysis").loc[order].reset_index()

# Reverse for horizontal plotting so first item appears at top
plot_summary = plot_summary.iloc[::-1].reset_index(drop=True)
y = np.arange(len(plot_summary))

xerr_lower = plot_summary["rate_percent"] - plot_summary["ci_low_percent"]
xerr_upper = plot_summary["ci_high_percent"] - plot_summary["rate_percent"]

fig, ax = plt.subplots(figsize=(9, 6))

ax.errorbar(
plot_summary["rate_percent"],
y,
xerr=[xerr_lower, xerr_upper],
fmt="o",
color="black",
ecolor="black",
elinewidth=1.8,
capsize=6,
markersize=8
)

ax.set_yticks(y)
ax.set_yticklabels(plot_summary["display_label"], fontsize=14)
ax.set_xlabel("Pooled ambulatory recovery rate (%)", fontsize=15)
ax.set_title("Summary of meta-analytic estimates", fontsize=18)
ax.set_xlim(0, 100)
ax.set_xticks([0, 25, 50, 75, 100])

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Make the actual plot area wider while keeping labels readable
plt.subplots_adjust(left=0.36, right=0.96, top=0.88, bottom=0.16)

fig.savefig("Figure5_summary_clean_expanded_paralysis.png", dpi=600, bbox_inches="tight")
fig.savefig("Figure5_summary_clean_expanded_paralysis.pdf", bbox_inches="tight")

plt.show()
# ============================================================
# 6. Leave-one-out sensitivity analysis for expanded 10
# ============================================================

loo_results = []

for study in expanded10["Study"]:
    temp = expanded10[expanded10["Study"] != study].copy()
    result = run_meta(
        temp,
        f"Leave-one-out analysis: excluding {study}",
        f"LOO_expanded_excluding_{study.replace(' ', '_')}"
    )
    result["excluded_study"] = study
    loo_results.append(result)

loo_summary = pd.DataFrame(loo_results)
loo_summary.to_csv("Table_leave_one_out_expanded10.csv", index=False)

print("\n===== Leave-one-out sensitivity summary: expanded 10 =====")
display(loo_summary)

# ============================================================
# 7. Funnel plot for expanded 10
# ============================================================

funnel = expanded10.copy()
funnel["p"] = funnel["event"] / funnel["n"]
funnel["se_p"] = np.sqrt((funnel["p"] * (1 - funnel["p"])) / funnel["n"])
funnel["precision"] = 1 / funnel["se_p"]

fig, ax = plt.subplots(figsize=FIGSIZE)

ax.scatter(
    funnel["p"],
    funnel["precision"],
    color="black",
    s=55
)

ax.set_xlabel("Ambulatory recovery rate")
ax.set_ylabel("Precision")
ax.set_title("Funnel plot: expanded analysis")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.tight_layout()

fig.savefig("Figure6_funnel_plot_expanded10.png", dpi=600, bbox_inches="tight")
fig.savefig("Figure6_funnel_plot_expanded10.pdf", bbox_inches="tight")

plt.show()

# ============================================================
# 8. Egger's regression test
#    Caution: limited interpretability with small number of studies
# ============================================================

# Standard normal deviate approach on raw proportions
funnel["SND"] = funnel["p"] / funnel["se_p"]
funnel["precision_for_egger"] = 1 / funnel["se_p"]

slope, intercept, r, p_value, std_err = stats.linregress(
    funnel["precision_for_egger"],
    funnel["SND"]
)

print("\n===== Publication bias =====")
print(f"Egger's regression intercept = {intercept:.3f}")
print(f"Egger's test p-value = {p_value:.3f}")
print("Note: Egger's test is exploratory because the number of studies is small.")

with open("Egger_test_expanded10.txt", "w") as f:
    f.write(f"Egger's regression intercept = {intercept:.3f}\n")
    f.write(f"Egger's test p-value = {p_value:.3f}\n")
    f.write("Note: Egger's test is exploratory because the number of studies is small.\n")

# ============================================================
# 9. Manuscript Table 1: Study characteristics
# ============================================================

table1 = data.copy()
table1["Recovery rate"] = (table1["event"] / table1["n"] * 100).map(lambda x: f"{x:.1f}%")

table1 = table1.rename(columns={
    "n": "Sample size",
    "event": "Ambulatory recovery events",
    "analysis_group": "Analysis category",
    "notes": "Cohort notes"
})

table1 = table1[[
    "Study",
    "Sample size",
    "Ambulatory recovery events",
    "Recovery rate",
    "Analysis category",
    "Cohort notes"
]]

table1.to_csv("Table1_study_characteristics_10studies.csv", index=False)

print("\n===== Table 1. Study characteristics =====")
display(table1)

# ============================================================
# 10. Manuscript Table 2: Meta-analysis results
# ============================================================

table2 = summary_results.copy()

table2_for_manuscript = pd.DataFrame({
    "Analysis": table2["analysis"],
    "Number of studies": table2["number_of_studies"],
    "Total patients": table2["total_patients"],
    "Total recovery events": table2["total_events"],
    "Crude recovery rate": table2["crude_recovery_rate"].map(lambda x: f"{x*100:.1f}%"),
    "Pooled ambulatory recovery rate": table2["pooled_ambulatory_recovery_rate"].map(lambda x: f"{x*100:.1f}%"),
    "95% CI": [
        f"{lo*100:.1f}–{hi*100:.1f}%"
        for lo, hi in zip(table2["ci_low"], table2["ci_high"])
    ],
    "I²": table2["I2"].map(lambda x: f"{x:.1f}%"),
    "Tau²": table2["tau2"].map(lambda x: f"{x:.4f}")
})

table2_for_manuscript.to_csv("Table2_meta_analysis_results_clean_expanded_paralysis.csv", index=False)

print("\n===== Table 2. Meta-analysis results =====")
display(table2_for_manuscript)

# ============================================================
# 11. Manuscript Table 3: Leave-one-out sensitivity
# ============================================================

loo_table = loo_summary.copy()
loo_table_for_manuscript = pd.DataFrame({
    "Excluded study": loo_table["excluded_study"],
    "Number of studies": loo_table["number_of_studies"],
    "Total patients": loo_table["total_patients"],
    "Pooled ambulatory recovery rate": loo_table["pooled_ambulatory_recovery_rate"].map(lambda x: f"{x*100:.1f}%"),
    "95% CI": [
        f"{lo*100:.1f}–{hi*100:.1f}%"
        for lo, hi in zip(loo_table["ci_low"], loo_table["ci_high"])
    ],
    "I²": loo_table["I2"].map(lambda x: f"{x:.1f}%")
})

loo_table_for_manuscript.to_csv("Table3_leave_one_out_sensitivity_expanded10.csv", index=False)

print("\n===== Table 3. Leave-one-out sensitivity analysis =====")
display(loo_table_for_manuscript)

print("\nAll figures and manuscript tables have been saved.")
# Out:
# ================================================
# Clean cohort analysis
# ================================================
#             Study    n  event         p    ci_low   ci_high analysis_group  \
# 0        Kim 2011   57     39  0.684211  0.563537  0.804884   Clean cohort
# 1    Tateiwa 2018   31     17  0.548387  0.373200  0.723574   Clean cohort
# 2     Ohashi 2017   82     50  0.609756  0.504173  0.715339   Clean cohort
# 3  Kinoshita 2023  113     70  0.619469  0.529949  0.708989   Clean cohort
# 4         Li 2024   37     22  0.594595  0.436393  0.752796   Clean cohort
# 5     Wanman 2025  111     61  0.549550  0.456990  0.642109   Clean cohort
#
#                          notes
# 0        Non-ambulatory cohort
# 1        Non-ambulatory cohort
# 2        Non-ambulatory cohort
# 3        Non-ambulatory cohort
# 4        Non-ambulatory cohort
# 5  Non-ambulatory >48 h cohort
# Pooled ambulatory recovery rate = 0.599
# 95% CI = 0.552–0.644
# I² = 0.0%
# Tau² = 0.0000
# ================================================
# Expanded analysis including additional abstract-based studies
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 0        Clean cohort                              Non-ambulatory cohort
# 1        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.565
# 95% CI = 0.494–0.634
# I² = 55.8%
# Tau² = 0.1069
# ================================================
# Complete paralysis subgroup
# ================================================
#          Study   n  event     p   ci_low  ci_high      analysis_group  \
# 9  Younsi 2021  28      7  0.25  0.08961  0.41039  Complete paralysis
#
#                              notes
# 9  Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.259
# 95% CI = 0.132–0.445
# I² = 0.0%
# Tau² = 0.0000
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py:1709: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return math.isfinite(val)
# ================================================
# Sensitivity analysis: expanded cohort excluding Gokaslan
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                            notes
# 0        Clean cohort            Non-ambulatory cohort
# 1        Clean cohort            Non-ambulatory cohort
# 2        Clean cohort            Non-ambulatory cohort
# 3        Clean cohort            Non-ambulatory cohort
# 4        Clean cohort            Non-ambulatory cohort
# 5        Clean cohort      Non-ambulatory >48 h cohort
# 6     Expanded cohort        Tumor-specific HCC cohort
# 8     Expanded cohort      Tumor-specific NSCLC cohort
# 9  Complete paralysis  Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.556
# 95% CI = 0.484–0.626
# I² = 57.3%
# Tau² = 0.1037
# ================================================
# Leave-one-out analysis: excluding Kim 2011
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 1        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.550
# 95% CI = 0.475–0.622
# I² = 54.6%
# Tau² = 0.1033
# ================================================
# Leave-one-out analysis: excluding Tateiwa 2018
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 0        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.566
# 95% CI = 0.488–0.641
# I² = 60.5%
# Tau² = 0.1251
# ================================================
# Leave-one-out analysis: excluding Ohashi 2017
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 0        Clean cohort                              Non-ambulatory cohort
# 1        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.556
# 95% CI = 0.474–0.636
# I² = 60.0%
# Tau² = 0.1381
# ================================================
# Leave-one-out analysis: excluding Kinoshita 2023
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 0        Clean cohort                              Non-ambulatory cohort
# 1        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.554
# 95% CI = 0.471–0.634
# I² = 58.8%
# Tau² = 0.1395
# ================================================
# Leave-one-out analysis: excluding Li 2024
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 0        Clean cohort                              Non-ambulatory cohort
# 1        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.561
# 95% CI = 0.482–0.637
# I² = 60.7%
# Tau² = 0.1279
# ================================================
# Leave-one-out analysis: excluding Wanman 2025
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 0        Clean cohort                              Non-ambulatory cohort
# 1        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.565
# 95% CI = 0.481–0.646
# I² = 59.8%
# Tau² = 0.1461
# ================================================
# Leave-one-out analysis: excluding Kim HCC 2011
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 0        Clean cohort                              Non-ambulatory cohort
# 1        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.580
# 95% CI = 0.514–0.644
# I² = 50.1%
# Tau² = 0.0779
# ================================================
# Leave-one-out analysis: excluding Gokaslan 1998
# ================================================
#              Study    n  event         p    ci_low   ci_high  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4          Li 2024   37     22  0.594595  0.436393  0.752796
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121
# 9      Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                            notes
# 0        Clean cohort            Non-ambulatory cohort
# 1        Clean cohort            Non-ambulatory cohort
# 2        Clean cohort            Non-ambulatory cohort
# 3        Clean cohort            Non-ambulatory cohort
# 4        Clean cohort            Non-ambulatory cohort
# 5        Clean cohort      Non-ambulatory >48 h cohort
# 6     Expanded cohort        Tumor-specific HCC cohort
# 8     Expanded cohort      Tumor-specific NSCLC cohort
# 9  Complete paralysis  Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.556
# 95% CI = 0.484–0.626
# I² = 57.3%
# Tau² = 0.1037
# ================================================
# Leave-one-out analysis: excluding Park NSCLC 2016
# ================================================
#             Study    n  event         p    ci_low   ci_high  \
# 0        Kim 2011   57     39  0.684211  0.563537  0.804884
# 1    Tateiwa 2018   31     17  0.548387  0.373200  0.723574
# 2     Ohashi 2017   82     50  0.609756  0.504173  0.715339
# 3  Kinoshita 2023  113     70  0.619469  0.529949  0.708989
# 4         Li 2024   37     22  0.594595  0.436393  0.752796
# 5     Wanman 2025  111     61  0.549550  0.456990  0.642109
# 6    Kim HCC 2011   14      4  0.285714  0.049071  0.522357
# 7   Gokaslan 1998   13     10  0.769231  0.540196  0.998266
# 9     Younsi 2021   28      7  0.250000  0.089610  0.410390
#
#        analysis_group                                              notes
# 0        Clean cohort                              Non-ambulatory cohort
# 1        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 9  Complete paralysis                    Complete motor paralysis cohort
# Pooled ambulatory recovery rate = 0.561
# 95% CI = 0.482–0.637
# I² = 60.7%
# Tau² = 0.1287
# ================================================
# Leave-one-out analysis: excluding Younsi 2021
# ================================================
#              Study    n  event         p    ci_low   ci_high   analysis_group  \
# 0         Kim 2011   57     39  0.684211  0.563537  0.804884     Clean cohort
# 1     Tateiwa 2018   31     17  0.548387  0.373200  0.723574     Clean cohort
# 2      Ohashi 2017   82     50  0.609756  0.504173  0.715339     Clean cohort
# 3   Kinoshita 2023  113     70  0.619469  0.529949  0.708989     Clean cohort
# 4          Li 2024   37     22  0.594595  0.436393  0.752796     Clean cohort
# 5      Wanman 2025  111     61  0.549550  0.456990  0.642109     Clean cohort
# 6     Kim HCC 2011   14      4  0.285714  0.049071  0.522357  Expanded cohort
# 7    Gokaslan 1998   13     10  0.769231  0.540196  0.998266  Expanded cohort
# 8  Park NSCLC 2016   39     23  0.589744  0.435366  0.744121  Expanded cohort
#
#                                                notes
# 0                              Non-ambulatory cohort
# 1                              Non-ambulatory cohort
# 2                              Non-ambulatory cohort
# 3                              Non-ambulatory cohort
# 4                              Non-ambulatory cohort
# 5                        Non-ambulatory >48 h cohort
# 6                          Tumor-specific HCC cohort
# 7  Anterior vertebrectomy; selected thoracic meta...
# 8                        Tumor-specific NSCLC cohort
# Pooled ambulatory recovery rate = 0.593
# 95% CI = 0.544–0.641
# I² = 15.7%
# Tau² = 0.0149
# ===== Leave-one-out sensitivity summary: expanded 10 =====
#                                             analysis  number_of_studies  \
# 0         Leave-one-out analysis: excluding Kim 2011                  9
# 1     Leave-one-out analysis: excluding Tateiwa 2018                  9
# 2      Leave-one-out analysis: excluding Ohashi 2017                  9
# 3   Leave-one-out analysis: excluding Kinoshita 2023                  9
# 4          Leave-one-out analysis: excluding Li 2024                  9
# 5      Leave-one-out analysis: excluding Wanman 2025                  9
# 6     Leave-one-out analysis: excluding Kim HCC 2011                  9
# 7    Leave-one-out analysis: excluding Gokaslan 1998                  9
# 8  Leave-one-out analysis: excluding Park NSCLC 2016                  9
# 9      Leave-one-out analysis: excluding Younsi 2021                  9
#
#    total_patients  total_events  crude_recovery_rate  \
# 0             468           264             0.564103
# 1             494           286             0.578947
# 2             443           253             0.571106
# 3             412           233             0.565534
# 4             488           281             0.575820
# 5             414           242             0.584541
# 6             511           299             0.585127
# 7             512           293             0.572266
# 8             486           280             0.576132
# 9             497           296             0.595573
#
#    pooled_ambulatory_recovery_rate    ci_low   ci_high         I2      tau2  \
# 0                         0.549857  0.475050  0.622476  54.616153  0.103256
# 1                         0.565829  0.487864  0.640667  60.486705  0.125143
# 2                         0.556462  0.474235  0.635708  60.023664  0.138141
# 3                         0.554083  0.471127  0.634131  58.800831  0.139452
# 4                         0.560790  0.481940  0.636686  60.687913  0.127864
# 5                         0.565168  0.481152  0.645601  59.772814  0.146080
# 6                         0.580487  0.514170  0.644019  50.053820  0.077866
# 7                         0.556256  0.484246  0.625978  57.302889  0.103691
# 8                         0.561176  0.482058  0.637301  60.721195  0.128734
# 9                         0.593380  0.543821  0.641108  15.702788  0.014851
#
#            Q  dof   excluded_study
# 0  17.627417    8         Kim 2011
# 1  20.246350    8     Tateiwa 2018
# 2  20.011839    8      Ohashi 2017
# 3  19.417867    8   Kinoshita 2023
# 4  20.349975    8          Li 2024
# 5  19.887048    8      Wanman 2025
# 6  16.017241    8     Kim HCC 2011
# 7  18.736631    8    Gokaslan 1998
# 8  20.367218    8  Park NSCLC 2016
# 9   9.490231    8      Younsi 2021
# ===== Publication bias =====
# Egger's regression intercept = -1.709
# Egger's test p-value = 0.001
# Note: Egger's test is exploratory because the number of studies is small.
#
# ===== Table 1. Study characteristics =====
#              Study  Sample size  Ambulatory recovery events Recovery rate  \
# 0         Kim 2011           57                          39         68.4%
# 1     Tateiwa 2018           31                          17         54.8%
# 2      Ohashi 2017           82                          50         61.0%
# 3   Kinoshita 2023          113                          70         61.9%
# 4          Li 2024           37                          22         59.5%
# 5      Wanman 2025          111                          61         55.0%
# 6     Kim HCC 2011           14                           4         28.6%
# 7    Gokaslan 1998           13                          10         76.9%
# 8  Park NSCLC 2016           39                          23         59.0%
# 9      Younsi 2021           28                           7         25.0%
#
#     Analysis category                                       Cohort notes
# 0        Clean cohort                              Non-ambulatory cohort
# 1        Clean cohort                              Non-ambulatory cohort
# 2        Clean cohort                              Non-ambulatory cohort
# 3        Clean cohort                              Non-ambulatory cohort
# 4        Clean cohort                              Non-ambulatory cohort
# 5        Clean cohort                        Non-ambulatory >48 h cohort
# 6     Expanded cohort                          Tumor-specific HCC cohort
# 7     Expanded cohort  Anterior vertebrectomy; selected thoracic meta...
# 8     Expanded cohort                        Tumor-specific NSCLC cohort
# 9  Complete paralysis                    Complete motor paralysis cohort
# ===== Table 2. Meta-analysis results =====
#                                             Analysis  Number of studies  \
# 0                              Clean cohort analysis                  6
# 1  Expanded analysis including additional abstrac...                 10
# 2                        Complete paralysis subgroup                  1
# 3  Sensitivity analysis: expanded cohort excludin...                  9
#
#    Total patients  Total recovery events Crude recovery rate  \
# 0             431                    259               60.1%
# 1             525                    303               57.7%
# 2              28                      7               25.0%
# 3             512                    293               57.2%
#
#   Pooled ambulatory recovery rate      95% CI     I²    Tau²
# 0                           59.9%  55.2–64.4%   0.0%  0.0000
# 1                           56.5%  49.4–63.4%  55.8%  0.1069
# 2                           25.9%  13.2–44.5%   0.0%  0.0000
# 3                           55.6%  48.4–62.6%  57.3%  0.1037
# ===== Table 3. Leave-one-out sensitivity analysis =====
#     Excluded study  Number of studies  Total patients  \
# 0         Kim 2011                  9             468
# 1     Tateiwa 2018                  9             494
# 2      Ohashi 2017                  9             443
# 3   Kinoshita 2023                  9             412
# 4          Li 2024                  9             488
# 5      Wanman 2025                  9             414
# 6     Kim HCC 2011                  9             511
# 7    Gokaslan 1998                  9             512
# 8  Park NSCLC 2016                  9             486
# 9      Younsi 2021                  9             497
#
#   Pooled ambulatory recovery rate      95% CI     I²
# 0                           55.0%  47.5–62.2%  54.6%
# 1                           56.6%  48.8–64.1%  60.5%
# 2                           55.6%  47.4–63.6%  60.0%
# 3                           55.4%  47.1–63.4%  58.8%
# 4                           56.1%  48.2–63.7%  60.7%
# 5                           56.5%  48.1–64.6%  59.8%
# 6                           58.0%  51.4–64.4%  50.1%
# 7                           55.6%  48.4–62.6%  57.3%
# 8                           56.1%  48.2–63.7%  60.7%
# 9                           59.3%  54.4–64.1%  15.7%
# All figures and manuscript tables have been saved.
